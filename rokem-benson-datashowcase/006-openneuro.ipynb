# %% [markdown]
# # Datasets on OpenNeuro.org
#
# There are many datasets on [OpenNeuro](https://openneuro.org/)! Each dataset has a unique identifier such as `ds003787` that can be found by searching the OpenNeuro website. All of OpenNeuro is in BIDS format and is available in Amazon's S3, in the `openneuro.org` S3 bucket.

# %%
from cloudpathlib import S3Path, S3Client
from pathlib import Path

# Set up our cache path:
cache_path = Path('/home/jovyan/cache')
if not cache_path.exists():
    cache_path.mkdir()

# Create the root S3Path for the NYU Retinotopy Dataset:
nyu_base_path = S3Path(
    's3://openneuro.org/ds003787/',
    client=S3Client(
        no_sign_request=True,
        local_cache_dir=cache_path))

# %%
# Let's see if it looks like a BIDS dataset!

from utils import ls

ls(nyu_base_path)
# Out:
# [S3Path('s3://openneuro.org/ds003787/derivatives'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj001'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj004'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj006'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj007'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj014'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj019'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj023'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj042'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj043'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj045'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj046'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj055'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj056'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj057'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj062'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj064'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj067'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj071'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj076'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj079'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj081'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj083'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj084'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj085'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj086'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj087'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj088'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj090'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj091'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj092'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj094'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj095'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj104'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj105'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj109'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj114'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj115'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj116'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj117'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj118'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj120'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj121'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj122'),
#  S3Path('s3://openneuro.org/ds003787/sub-wlsubj126'),
#  S3Path('s3://openneuro.org/ds003787/.gitattributes'),
#  S3Path('s3://openneuro.org/ds003787/CHANGES'),
#  S3Path('s3://openneuro.org/ds003787/README'),
#  S3Path('s3://openneuro.org/ds003787/annex-uuid'),
#  S3Path('s3://openneuro.org/ds003787/dataset_description.json'),
#  S3Path('s3://openneuro.org/ds003787/participants.json'),
#  S3Path('s3://openneuro.org/ds003787/participants.tsv')]

# %%
# Let's look at the participants!
import pandas as pd

pd.read_csv((nyu_base_path / 'participants.tsv'), sep='\t')
# Out:
#     participant_id  age sex    group
# 0    sub-wlsubj001   29   F  control
# 1    sub-wlsubj004   49   M  control
# 2    sub-wlsubj006   37   F  control
# 3    sub-wlsubj007   32   F  control
# 4    sub-wlsubj014   32   F  control
# 5    sub-wlsubj019   35   M  control
# 6    sub-wlsubj023   27   M  control
# 7    sub-wlsubj042   39   M  control
# 8   sub-wlsubj043    29   F  control
# 9    sub-wlsubj045   30   M  control
# 10   sub-wlsubj046   37   M  control
# 11   sub-wlsubj055   22   M  control
# 12   sub-wlsubj056   23   M  control
# 13   sub-wlsubj057   23   M  control
# 14   sub-wlsubj062   37   F  control
# 15   sub-wlsubj064   25   F  control
# 16   sub-wlsubj067   35   F  control
# 17   sub-wlsubj071   22   F  control
# 18   sub-wlsubj076   26   F  control
# 19   sub-wlsubj079   36   F  control
# 20   sub-wlsubj081   29   F  control
# 21   sub-wlsubj083   25   F  control
# 22   sub-wlsubj084   23   M  control
# 23   sub-wlsubj085   22   M  control
# 24   sub-wlsubj086   24   F  control
# 25   sub-wlsubj087   20   M  control
# 26   sub-wlsubj088   21   M  control
# 27   sub-wlsubj090   21   M  control
# 28   sub-wlsubj091   21   F  control
# 29   sub-wlsubj092   23   F  control
# 30  sub-wlsubj094    29   M  control
# 31   sub-wlsubj095   34   F  control
# 32   sub-wlsubj104   28   F  control
# 33   sub-wlsubj105   27   M  control
# 34   sub-wlsubj109   31   F  control
# 35   sub-wlsubj114   31   M  control
# 36   sub-wlsubj115   34   M  control
# 37   sub-wlsubj116   26   F  control
# 38   sub-wlsubj117   30   F  control
# 39   sub-wlsubj118   32   F  control
# 40   sub-wlsubj120   24   F  control
# 41   sub-wlsubj121   32   M  control
# 42   sub-wlsubj122   32   F  control
# 43   sub-wlsubj126   32   F  control

# %% [markdown]
# ## Loading a subject using FreeSurfer and neuropythy

# %%
# Import neuropythy
import neuropythy as ny

# Tell neuropythy where we want to keep cache data.
ny.config['data_cache_root'] = '/home/jovyan/cache'

# %%
# Ask neuropythy to load a FreeSurfer subject:
sub = ny.freesurfer_subject(
    's3://openneuro.org/ds003787/derivatives/freesurfer/sub-wlsubj042')

# %%
ny.cortex_plot((sub.lh, sub.rh), surface='white')
